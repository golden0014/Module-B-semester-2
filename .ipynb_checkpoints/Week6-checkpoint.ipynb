# %% [markdown]
# # Week 6 - Bivariate Analysis, part 2

# %% [markdown]
# # 1. Lesson: no lesson this week

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you wanted to show the nitrate and phosphate level in a water sample.  What are the advantages and disadvantages of showing this as an area plot, as opposed to two separate line graphs?  How would you adjust the graphs shown to improve the presentation?

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# C:\Users\golde\AppData\Local\Temp\ipykernel_29132\2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series_2 =  100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series_2)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# C:\Users\golde\AppData\Local\Temp\ipykernel_29132\1726504607.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
df = pd.DataFrame({'ser1': time_series, 'ser2': time_series_2}, index = datearray)
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# **Suppose you wanted to show the nitrate and phosphate level in a water sample.  What are the advantages and disadvantages of showing this as an area plot, as opposed to two separate line graphs?**
# Advantages: direct comparison between both line graphs, with colors to visualize the gaps between the two
# Disadvantages: if the higher trending chemical dips below the lower trending chemical, the visibility is decreased
#
# **How would you adjust the graphs shown to improve the presentation?**
# I would add a title, axes titles, and more descriptive labels for each type of data.

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do:
#
# - Find correlations between pairs of variables.
#
# - Draw scatterplots, especially when the correlation is large.
#
# - Draw pairplots.
#
# - Draw line graphs and/or area graphs when there is date or time data together with numerical data.
#
# ### Conclusions:
#
# - Explain what conclusions you would draw from this analysis: are the data what you expect?  Are the data likely to be usable?  If the data are not useable, find some new data!
#
# - Do you see any outliers?  (Data points that are far from the rest of the data).
#
# - Are any data items highly correlated with each other, suggesting that they are redundant?
#
# - For the line plots, do you see a trend or pattern over time?  Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
#
# - Can you think of any confounding variables?  (Third variables that could explain any correlations between other variables.  These third variables may or may not be reported in the dataset.)

# %% [markdown]
# **Import Additional Libraries**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Load Data**

# %%
diabetes_indicators = pd.read_csv('Modified_Datasets/diabetes_indicators.csv')

# %%
obesity = pd.read_csv('Modified_Datasets/obesity.csv')

# %%
cervical_cancer = pd.read_csv('Modified_Datasets/cervical_cancer.csv')

# %% [markdown]
# **Diabetes Indicators**

# %%
# Correlations
sns.heatmap(diabetes_indicators.corr())
# Out:
# <Axes: >

# %%
# Scatterplots
plt.scatter(diabetes_indicators['Age'], diabetes_indicators['BMI'])
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('BMI vs. Age')
plt.show()

# %%
# Pairplots
sns.pairplot(diabetes_indicators)

# %%
# Line Graphs/Area Graphs
plt.plot(diabetes_indicators['MentHlth'], diabetes_indicators['PhysHlth'])
plt.xlabel('Mental Health')
plt.ylabel('Physical Health')
plt.title('Physical Health vs. Mental Health')
plt.show()

# %%
# Leaving line plot above as is after testing multiple combinations of columns and getting essentially the same result

# %% [markdown]
# *Conclusions*
# Explain what conclusions you would draw from this analysis: are the data what you expect? Are the data likely to be usable? If the data are not useable, find some new data!
# Data is as expected and usable.
#
# Do you see any outliers? (Data points that are far from the rest of the data).
# No outliers spotted.
#
# Are any data items highly correlated with each other, suggesting that they are redundant?
# Physical health and genetic health have a positive correlation but that does not necessarily mean they are redundant.
#
# For the line plots, do you see a trend or pattern over time? Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
# After trying multiple combinations of columns, not seeing a pattern. No time unit in data to compare changes over time.
#
# Can you think of any confounding variables? (Third variables that could explain any correlations between other variables. These third variables may or may not be reported in the dataset.)
# None.

# %% [markdown]
# **Obesity**

# %%
# Correlations
sns.heatmap(obesity.select_dtypes(include = 'number').corr())
# Out:
# <Axes: >

# %%
# Scatterplots
plt.scatter(obesity['Height (m)'], obesity['Weight (kg)'])
plt.xlabel('Height (m)')
plt.ylabel('Weight (kg)')
plt.title('Weight vs Height')
plt.show()

# %%
# Pairplots
sns.pairplot(obesity)

# %%
# Line Graphs/Area Graphs
plt.plot(obesity['Physical Activity'], obesity['Weight (kg)'])
plt.xlabel('Physical Activity (0 = None, 1 = 1-2 days/wk, 2 = 2-4 days/wk, 3 = 4-5 days/wk)')
plt.ylabel('Weight (kg)')
plt.title('Weight vs. Physical Activity')
plt.show()

# %% [markdown]
# *Conclusions*
# Explain what conclusions you would draw from this analysis: are the data what you expect? Are the data likely to be usable? If the data are not useable, find some new data!
# Data is as expected and usable.
#
# Do you see any outliers? (Data points that are far from the rest of the data).
# No outliers spotted.
#
# Are any data items highly correlated with each other, suggesting that they are redundant?
# Height and being male are highly correlated (although not relevant for the problem at hand). Weight and family history of being overweight are correlated but not necessarily redundant.
#
# For the line plots, do you see a trend or pattern over time? Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
# No time data to detect changes over time.
#
# Can you think of any confounding variables? (Third variables that could explain any correlations between other variables. These third variables may or may not be reported in the dataset.)
# None.

# %% [markdown]
# **Cervical Cancer**

# %%
# Correlations
sns.heatmap(cervical_cancer.corr())
# Out:
# <Axes: >

# %%
# Numerical printout
corr = cervical_cancer.corr()

sorted_corr = (
    corr.where(~np.eye(corr.shape[0], dtype = bool))
        .unstack()                # turn matrix into long Series
        .drop_duplicates()        # remove mirrored duplicates
        .sort_values(ascending=False)
)

print(sorted_corr.head(10))
# Out:
# STDs:condylomatosis               STDs:vulvo-perineal condylomatosis    0.987857
# STDs: Time since first diagnosis  STDs: Time since last diagnosis       0.930907
# STDs                              STDs (number)                         0.918403
#                                   STDs: Number of diagnosis             0.906430
# STDs (number)                     STDs:condylomatosis                   0.899376
#                                   STDs: Number of diagnosis             0.896987
#                                   STDs:vulvo-perineal condylomatosis    0.890543
# Dx:Cancer                         Dx:HPV                                0.886441
# IUD                               IUD (years)                           0.745957
# Schiller                          Biopsy                                0.728870
# dtype: float64

# %%
# Scatterplots
plt.scatter(cervical_cancer['STDs (number)'], cervical_cancer['Dx:Cancer'])
plt.xlabel('# of STDs')
plt.ylabel('Cancer Diagnosis')
plt.title('Cancer Diagnosis vs. # of STDs')
plt.show()

# %%
# Pairplots
sns.pairplot(cervical_cancer)

# %%
# Line Graphs/Area Graphs
plt.plot(cervical_cancer['Hormonal Contraceptives (years)'], cervical_cancer['Dx:Cancer'])
plt.xlabel('Hormonal Contraceptives (years)')
plt.ylabel('Cancer Diagnosis')
plt.title('Cancer Diagnosis vs. Hormonal Contraceptives')
plt.show()

# %%
# Difficult to plot line graphs with no time data

# %% [markdown]
# *Conclusions*
# Explain what conclusions you would draw from this analysis: are the data what you expect? Are the data likely to be usable? If the data are not useable, find some new data!
# Data is as expected and usable.
#
# Do you see any outliers? (Data points that are far from the rest of the data).
# No outliers spotted.
#
# Are any data items highly correlated with each other, suggesting that they are redundant?
# Yes but not necessarily redundant.
#
# For the line plots, do you see a trend or pattern over time? Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
# No time data to plot.
#
# Can you think of any confounding variables? (Third variables that could explain any correlations between other variables. These third variables may or may not be reported in the dataset.)
# None.

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 86-98 of the Storytelling With Data book as best you can.  (The second half of chapter three).  You do not have to get the exact data values right, just the overall look and feel.

# %%
x = list(range(1,13))
red = [151, 180, 245, 150, 170, 150, 110, 155, 125, 105, 125, 145]
blue = [151, 180, 246, 150, 170, 155, 113, 200, 160, 145, 150, 170]

plt.plot(x, blue, c = 'blue', label = 'Ticket Volume Received', linewidth = 2, marker = 'D', markerfacecolor = 'white')
plt.plot(x, red, c = 'red', label = 'Ticket Volume Processed', linewidth = 2, marker = 'D')
plt.xticks(ticks = x, labels = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'], rotation = 45)
plt.ylim(0,300)
plt.yticks(list(range(0, 301, 50)))
plt.grid(axis = 'y', linestyle = '-', linewidth = 0.8, alpha = 0.7)
plt.legend(loc = 'lower center', ncol = 2, bbox_to_anchor = (0.5, -0.3), frameon = False)
plt.show()
